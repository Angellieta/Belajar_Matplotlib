# %% [markdown]
# ## Import Modules

# %%
# %matplotlib notebook

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.3.2
# 1.19.2

# %% [markdown]
# # Style Sheets

# %% [markdown]
# ## Predefined Styles

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.title('Contoh Bar Plot')
plt.xlabel('Kategori')
plt.ylabel('Jumlah')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Membuat Style Sendiri

# %% [markdown]
# - axes.titlesize : 24
# - axes.labelsize : 20
# - lines.linewidth : 3
# - lines.markersize : 10
# - xtick.labelsize : 16
# - ytick.labelsize : 16

# %%
plt.style.use('C:/Users/Angel Lieta/Documents/PERKULIAHAN/SEMESTER 3/(6) Visualisasi Data/Belajar_Matplotlib/style_ku.mplstyle')

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.title('Contoh Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ## Menerapkan multiple style

# %%
plt.style.use(['seaborn', 'dark_background'])

# %%
x = np.linspace(1, 10, 15)

plt.plot(x, x, 'bs-', label='lin')
plt.plot(x, np.log(x), 'ro-', label='log')

plt.legend()
plt.title('Contoh Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %% [markdown]
# ## Menerapkan temporary styling

# %%
plt.style.use('ggplot')

plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %%
with plt.style.context('dark_background'):
    plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %%
plt.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">
